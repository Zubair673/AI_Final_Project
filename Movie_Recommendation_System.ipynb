# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.neighbors import NearestNeighbors
from surprise import Dataset, Reader, KNNBasic, SVD
from surprise.model_selection import cross_validate

# %%
movies = pd.read_csv(r"C:\Users\nmc\AppData\Local\Temp\movies.csv")
ratings = pd.read_csv(r"C:\Users\nmc\AppData\Local\Temp\ratings.csv")

# %%
print(movies.head())
print(ratings.head())

print(movies.shape)
print(ratings.shape)

print(movies.isnull().sum())
print(ratings.isnull().sum())

print(ratings.describe())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# (9742, 3)
# (100836, 4)
# movieId    0
# title      0
# genres     0
# dtype: int64
# userId       0
# movieId      0
# rating       0
# timestamp    0
# ...

# %%
sns.histplot(ratings["rating"])
plt.show()

# %%
user_activity = ratings.groupby("userId")["rating"].count()
sns.histplot(user_activity)
plt.show()

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\nmc\anaconda_projects\29e8c118-5f9f-4736-9334-e6d320a1b638
